# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("SP.csv")
df
# Out:
#     Order No.       Product Name  Quantity Ordered  Price Customer Name  \
# 0         101           Lifebuoy             100.0     10        Ashley
# 1         102  Head and Shoulder              50.0     60       Saniton
# 2         103            Sunslik              50.0     70         Allan
# 3         104             Dettol             200.0     25         Andre
# 4         105            Comfort             150.0     45        Rutvek
# 5         106            Cinthol              70.0     26        Sweyne
# 6         107              Liril              30.0     40     Saiprasad
# 7         108              Pears              35.0     30        Ashley
# 8         109                Lux             150.0     30        Ashley
# 9         110               Dove              69.0     67         Allan
# 10        111          Patanjali             170.0     12         Andre
# 11        112            Santoor              65.0     45        Rutvek
# ...

# %%
df['Price'].mean()
# Out:
# 42.391304347826086

# %%
df['Price'].median()
# Out:
# 40.0

# %%
df['Customer Name'].mode()
# Out:
# 0    Sweyne
# Name: Customer Name, dtype: object

# %%
df.head()
# Out:
#    Order No.       Product Name  Quantity Ordered  Price Customer Name  \
# 0        101           Lifebuoy             100.0     10        Ashley
# 1        102  Head and Shoulder              50.0     60       Saniton
# 2        103            Sunslik              50.0     70         Allan
# 3        104             Dettol             200.0     25         Andre
# 4        105            Comfort             150.0     45        Rutvek
#
#         State
# 0         Goa
# 1   Karnataka
# 2      Punjab
# 3     Kashmir
# 4  Maharastra

# %%
df.tail()
# Out:
#     Order No. Product Name  Quantity Ordered  Price Customer Name       State
# 18        119     Maxfresh             200.0     90        Rutvek     Kashmir
# 19        120         Lays             100.0     10        Sweyne  Maharastra
# 20        113      Medimix             115.0     20        Sweyne      Punjab
# 21        113      Medimix               NaN     20        Sweyne      Punjab
# 22        113      Medimix               NaN     20        Sweyne      Punjab

# %%
df.count()
# Out:
# Order No.           23
# Product Name        23
# Quantity Ordered    21
# Price               23
# Customer Name       23
# State               23
# dtype: int64

# %%
df.shape
# Out:
# (23, 6)

# %%
df['Price'].std()
# Out:
# 26.09203837194714

# %%
df['Price'].var()
# Out:
# 680.7944664031619

# %%
df['Price'].min()
# Out:
# 10

# %%
df['Price'].max()
# Out:
# 100

# %%
df.describe()
# Out:
#         Order No.  Quantity Ordered       Price
# count   23.000000         21.000000   23.000000
# mean   110.826087         91.571429   42.391304
# std      5.564924         54.533083   26.092038
# min    101.000000         21.000000   10.000000
# 25%    106.500000         50.000000   20.000000
# 50%    112.000000         69.000000   40.000000
# 75%    114.500000        115.000000   60.000000
# max    120.000000        200.000000  100.000000

# %%
df.drop_duplicates()
# Out:
#     Order No.       Product Name  Quantity Ordered  Price Customer Name  \
# 0         101           Lifebuoy             100.0     10        Ashley
# 1         102  Head and Shoulder              50.0     60       Saniton
# 2         103            Sunslik              50.0     70         Allan
# 3         104             Dettol             200.0     25         Andre
# 4         105            Comfort             150.0     45        Rutvek
# 5         106            Cinthol              70.0     26        Sweyne
# 6         107              Liril              30.0     40     Saiprasad
# 7         108              Pears              35.0     30        Ashley
# 8         109                Lux             150.0     30        Ashley
# 9         110               Dove              69.0     67         Allan
# 10        111          Patanjali             170.0     12         Andre
# 11        112            Santoor              65.0     45        Rutvek
# ...

# %%
df.dropna()
# Out:
#     Order No.       Product Name  Quantity Ordered  Price Customer Name  \
# 0         101           Lifebuoy             100.0     10        Ashley
# 1         102  Head and Shoulder              50.0     60       Saniton
# 2         103            Sunslik              50.0     70         Allan
# 3         104             Dettol             200.0     25         Andre
# 4         105            Comfort             150.0     45        Rutvek
# 5         106            Cinthol              70.0     26        Sweyne
# 6         107              Liril              30.0     40     Saiprasad
# 7         108              Pears              35.0     30        Ashley
# 8         109                Lux             150.0     30        Ashley
# 9         110               Dove              69.0     67         Allan
# 10        111          Patanjali             170.0     12         Andre
# 11        112            Santoor              65.0     45        Rutvek
# ...
