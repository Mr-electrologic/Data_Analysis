# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales.csv")
df
# Out:
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE  STATE
# 0        101              NaN         2871     2003   Motorcycles     NY
# 1        102             49.0         6954     2004        Planes     CA
# 2        103             49.0         5205     2003   Motorcycles     CA
# 3        104             37.0         3966     2004   Motorcycles     NY
# 4        105             23.0         5373     2003  Classic Cars     PA
# 5        106             28.0         3189     2004   Motorcycles     NJ
# 6        107             34.0         3677     2004   Motorcycles     CT
# 7        108             36.0         4100     2005   Motorcycles     MA
# 8        109             37.0         7374     2003  Classic Cars     CA
# 9        110             21.0         4860     2005  Classic Cars     NY
# 10       111             34.0         8015     2003  Classic Cars     CA
# 11       112             23.0         2333     2004   Motorcycles     NY
# ...

# %%
df.mean()
# Out:
# C:\Users\Saiprasad V. Anvekar\AppData\Local\Temp\ipykernel_11352\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# ORDER_ID            113.000
# QUANTITYORDERED      34.625
# SALES_PRICE        5421.560
# YEAR_ID            2003.920
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Saiprasad V. Anvekar\AppData\Local\Temp\ipykernel_11352\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ORDER_ID            113.0
# QUANTITYORDERED      34.0
# SALES_PRICE        5373.0
# YEAR_ID            2004.0
# dtype: float64

# %%
df["YEAR_ID"].mode()
# Out:
# 0    2004
# Name: YEAR_ID, dtype: int64

# %%
df.head()
# Out:
#    ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE STATE
# 0       101              NaN         2871     2003   Motorcycles    NY
# 1       102             49.0         6954     2004        Planes    CA
# 2       103             49.0         5205     2003   Motorcycles    CA
# 3       104             37.0         3966     2004   Motorcycles    NY
# 4       105             23.0         5373     2003  Classic Cars    PA

# %%
df.tail()
# Out:
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE STATE
# 20       121             29.0         6463     2004  Classic Cars    MA
# 21       122             39.0         7380     2004        Planes    PA
# 22       123             27.0         3704     2004        Planes    NY
# 23       124             34.0         6434     2005        Planes    CA
# 24       125             45.0         3747     2005   Motorcycles    CA

# %%
df.count()
# Out:
# ORDER_ID           25
# QUANTITYORDERED    24
# SALES_PRICE        25
# YEAR_ID            25
# PRODUCTLINE        25
# STATE              25
# dtype: int64

# %%
df.dtypes
# Out:
# ORDER_ID             int64
# QUANTITYORDERED    float64
# SALES_PRICE          int64
# YEAR_ID              int64
# PRODUCTLINE         object
# STATE               object
# dtype: object

# %%
df.isnull()
# Out:
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID  PRODUCTLINE  STATE
# 0      False             True        False    False        False  False
# 1      False            False        False    False        False  False
# 2      False            False        False    False        False  False
# 3      False            False        False    False        False  False
# 4      False            False        False    False        False  False
# 5      False            False        False    False        False  False
# 6      False            False        False    False        False  False
# 7      False            False        False    False        False  False
# 8      False            False        False    False        False  False
# 9      False            False        False    False        False  False
# 10     False            False        False    False        False  False
# 11     False            False        False    False        False  False
# ...

# %%
new_row={'ORDER_ID':500,'QUANTITYORDERED':10.0,'SALES_PRICE':3000,'YEAR_ID':2007,'PRODUCTLINE':'Planes','STATE':'CY'}
df=df.append(new_row,ignore_index=True)
df
# Out:
# C:\Users\Saiprasad V. Anvekar\AppData\Local\Temp\ipykernel_11352\3880067368.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(new_row,ignore_index=True)
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE  STATE
# 0        101              NaN         2871     2003   Motorcycles     NY
# 1        102             49.0         6954     2004        Planes     CA
# 2        103             49.0         5205     2003   Motorcycles     CA
# 3        104             37.0         3966     2004   Motorcycles     NY
# 4        105             23.0         5373     2003  Classic Cars     PA
# 5        106             28.0         3189     2004   Motorcycles     NJ
# 6        107             34.0         3677     2004   Motorcycles     CT
# 7        108             36.0         4100     2005   Motorcycles     MA
# ...

# %%
df=df.drop(22)
df
# Out:
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE  STATE
# 0        101              NaN         2871     2003   Motorcycles     NY
# 1        102             49.0         6954     2004        Planes     CA
# 2        103             49.0         5205     2003   Motorcycles     CA
# 3        104             37.0         3966     2004   Motorcycles     NY
# 4        105             23.0         5373     2003  Classic Cars     PA
# 5        106             28.0         3189     2004   Motorcycles     NJ
# 6        107             34.0         3677     2004   Motorcycles     CT
# 7        108             36.0         4100     2005   Motorcycles     MA
# 8        109             37.0         7374     2003  Classic Cars     CA
# 9        110             21.0         4860     2005  Classic Cars     NY
# 10       111             34.0         8015     2003  Classic Cars     CA
# 11       112             23.0         2333     2004   Motorcycles     NY
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#     ORDER_ID  QUANTITYORDERED  SALES_PRICE  YEAR_ID   PRODUCTLINE  STATE
# 0        101              NaN         2871     2003   Motorcycles     NY
# 1        102             49.0         6954     2004        Planes     CA
# 2        103             49.0         5205     2003   Motorcycles     CA
# 3        104             37.0         3966     2004   Motorcycles     NY
# 4        105             23.0         5373     2003  Classic Cars     PA
# 5        106             28.0         3189     2004   Motorcycles     NJ
# 6        107             34.0         3677     2004   Motorcycles     CT
# 7        108             36.0         4100     2005   Motorcycles     MA
# 8        109             37.0         7374     2003  Classic Cars     CA
# 9        110             21.0         4860     2005  Classic Cars     NY
# 10       111             34.0         8015     2003  Classic Cars     CA
# 11       112             23.0         2333     2004   Motorcycles     NY
# ...

# %%
plt.scatter(df['QUANTITYORDERED'],df['YEAR_ID'])
plt.show()

# %%
plt.bar(df['QUANTITYORDERED'],df['YEAR_ID'])
plt.show()
